# %%
results = """{
  "hasPrevious": false,
  "hasNext": false,
  "pageNumber": 1,
  "totalPages": 1,
  "totalResults": 10,
  "result": [
    {
      "id": "bb0f9727-5181-4abe-ba65-a93049373261",
      "name": "/document/video:71702",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A71702?alt=media&token=f0303fc3-e6c6-493c-ab33-d7085ea45038",
      "size": "56459B",
      "owner": "tbotalla@fi.uba.ar",
      "title": "sbsb",
      "description": "sbabav",
      "location": null,
      "visibility": "public",
      "thumbnail": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A71702_thumb?alt=media&token=85ab34ca-af20-4892-8ff1-4b9ff16688f8",
      "createdAt": "2020-07-27T23:11:23.070Z",
      "updatedAt": "2020-07-27T23:11:23.070Z"
    },
    {
      "id": "f0b857db-2083-4d86-8090-12342108277d",
      "name": "/document/video:6052",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A6052?alt=media&token=bfc8ed45-f2d2-4048-bfab-d1deb547f90e",
      "size": "14525B",
      "owner": "admin1005",
      "title": "un videaso",
      "description": "el videaso",
      "location": null,
      "visibility": "public",
      "thumbnail": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A6052_thumb?alt=media&token=cd1b5c89-bc32-478e-a840-757aa000e273",
      "createdAt": "2020-07-20T19:00:28.625Z",
      "updatedAt": "2020-07-20T19:00:28.625Z"
    },
    {
      "id": "cbee4f93-3fdb-4ae3-a0d7-aa05cb4c5502",
      "name": "/document/video:64051",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A64051?alt=media&token=d2e7f517-26ae-42b7-8a08-a4b5f8368383",
      "size": "75585B",
      "owner": "admin1005",
      "title": "sam",
      "description": "latino",
      "location": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A64051?alt=media&token=d2e7f517-26ae-42b7-8a08-a4b5f8368383",
      "visibility": "private",
      "thumbnail": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A64051_thumb?alt=media&token=639981c0-9b46-415b-9d8f-86e38803eabf",
      "createdAt": "2020-07-19T07:12:54.410Z",
      "updatedAt": "2020-07-19T07:12:54.410Z"
    },
    {
      "id": "37bfb94e-8a2a-4bfa-8d42-5f1c44fa7dbb",
      "name": "/document/video:6196",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A6196?alt=media&token=2865b239-f3f7-4cef-873d-aa891ee126fd",
      "size": "916947B",
      "owner": "admin1005",
      "title": "un video",
      "description": "el video",
      "location": null,
      "visibility": "public",
      "thumbnail": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A6196_thumb?alt=media&token=d4b4eac4-bbf1-4697-b5c2-30de9543b38f",
      "createdAt": "2020-07-19T04:01:37.037Z",
      "updatedAt": "2020-07-19T04:01:37.037Z"
    },
    {
      "id": "56b38c82-be98-463c-8c52-90dd42d124b8",
      "name": "/document/video:6017",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A6017?alt=media&token=f6b582ef-d2b4-4050-8bdc-dc8539857165",
      "size": "102801B",
      "owner": "admin9",
      "title": "the office - Pam pong",
      "description": "Pam pong angela",
      "location": null,
      "visibility": "public",
      "thumbnail": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A6017_thumb?alt=media&token=d71ff2d8-7f4d-4f45-8212-664e45e9b814",
      "createdAt": "2020-07-06T20:57:54.868Z",
      "updatedAt": "2020-07-06T20:57:54.868Z"
    },
    {
      "id": "ba771d09-e114-465b-b523-f3a50cdd8b8b",
      "name": "/document/video:59965",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A59965?alt=media&token=a888ced1-1e80-46de-aa1d-0dcc8d415a06",
      "size": "29792B",
      "owner": "admin9",
      "title": "sjshsj",
      "description": "dbbssbsb",
      "location": null,
      "visibility": "public",
      "thumbnail": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A59965_thumb?alt=media&token=00346bdb-b48c-43da-82e0-68823c7439d5",
      "createdAt": "2020-07-04T20:42:57.782Z",
      "updatedAt": "2020-07-04T20:42:57.782Z"
    },
    {
      "id": "68b432b7-6419-4f05-9358-de3395110290",
      "name": "/document/video:59965",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A59965?alt=media&token=51caac3f-ed11-4a4b-987a-d2c0a1ebf90e",
      "size": "29792B",
      "owner": "admin9",
      "title": "ymik",
      "description": "dbsbdb",
      "location": null,
      "visibility": "private",
      "thumbnail": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A59965_thumb?alt=media&token=c1044c3a-7013-40a3-b94d-91f1d899ecbf",
      "createdAt": "2020-07-04T20:37:00.848Z",
      "updatedAt": "2020-07-04T20:37:00.848Z"
    },
    {
      "id": "9874951e-caf6-4d6b-9000-3a5d77f9a8b5",
      "name": "/document/video:51661",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A51661?alt=media&token=354a8901-3adc-417f-adfe-1e4a519389c2",
      "size": "28057B",
      "owner": "admin9",
      "title": "Nacho.o works",
      "description": "Una desc apropiada",
      "location": null,
      "visibility": "public",
      "thumbnail": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A51661_thumb?alt=media&token=7816f3f0-b48c-4c3c-ae16-eedb473eb26f",
      "createdAt": "2020-07-04T16:05:51.386Z",
      "updatedAt": "2020-07-04T19:30:38.737Z"
    },
    {
      "id": "c1b0b83f-69c0-48fe-937b-83883180fb16",
      "name": "/document/video:5527",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A5527?alt=media&token=8acda06c-d8d9-40e8-b6da-3341f6a2f2b2",
      "size": "371771B",
      "owner": "admin",
      "title": "rick on love",
      "description": "rise above focus on taller",
      "location": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A5527_thumb?alt=media&token=d2740f4b-153b-40dd-91b2-ea08a65ec651",
      "visibility": "public",
      "thumbnail": "https://i.ytimg.com/vi/VGelJhg4B9Q/maxresdefault.jpg",
      "createdAt": "2020-06-08T01:18:12.551Z",
      "updatedAt": "2020-07-04T19:03:26.428Z"
    },
    {
      "id": "6e382016-dcf5-42bf-9377-4c09e8d656eb",
      "name": "/document/video:43983",
      "path": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A43983?alt=media&token=94633e3c-3e89-4fc4-8d79-bab44ebd193b",
      "size": "81862B",
      "owner": "admin",
      "title": "rick",
      "description": "h jbl kkjj",
      "location": "https://firebasestorage.googleapis.com/v0/b/chotuve-63203.appspot.com/o/videos%2Fdocument%2Fvideo%3A43983_thumb?alt=media&token=9b9317bb-fa61-4d50-810f-d97d1032b002",
      "visibility": "private",
      "thumbnail": "https://i.pinimg.com/originals/a0/61/30/a061301eada06f471273cffad2df253f.jpg",
      "createdAt": "2020-06-07T22:33:54.103Z",
      "updatedAt": "2020-06-07T22:33:54.103Z"
    }
  ]
}
"""

# %%
import json

import pandas as pd

# %%
from business_rules import run_all
from business_rules.actions import BaseActions, rule_action, fields
from business_rules.variables import BaseVariables, numeric_rule_variable

class VideoVariables(BaseVariables):

    def __init__(self, video):
        self.video = video

    @numeric_rule_variable
    def videos_by_user(self):
        return self.video.videos_by_user

class VideoActions(BaseActions):

    def __init__(self, video):
        self.video = video

    @rule_action(params={"importance": fields.FIELD_NUMERIC})
    def set_importance(self, importance):
        self.video.importance += importance

class Video:
    def __init__(self, args):
        self.id = args["id"]
        self.title = args["title"]
        self.videos_by_user = args["videosByUser"]
        self.importance = 0
    
    def __str__(self):
        return self.importance

# %%
res = json.loads(results)["result"]

df = pd.DataFrame(res)

df["videosByUser"] =  df["owner"].groupby(df["owner"]).transform("count")

# %%
df
# Out:
#                                      id                   name  \
# 0  bb0f9727-5181-4abe-ba65-a93049373261  /document/video:71702
# 1  f0b857db-2083-4d86-8090-12342108277d   /document/video:6052
# 2  cbee4f93-3fdb-4ae3-a0d7-aa05cb4c5502  /document/video:64051
# 3  37bfb94e-8a2a-4bfa-8d42-5f1c44fa7dbb   /document/video:6196
# 4  56b38c82-be98-463c-8c52-90dd42d124b8   /document/video:6017
# 5  ba771d09-e114-465b-b523-f3a50cdd8b8b  /document/video:59965
# 6  68b432b7-6419-4f05-9358-de3395110290  /document/video:59965
# 7  9874951e-caf6-4d6b-9000-3a5d77f9a8b5  /document/video:51661
# 8  c1b0b83f-69c0-48fe-937b-83883180fb16   /document/video:5527
# 9  6e382016-dcf5-42bf-9377-4c09e8d656eb  /document/video:43983
#
#                                                 path     size  \
# 0  https://firebasestorage.googleapis.com/v0/b/ch...   56459B
# 1  https://firebasestorage.googleapis.com/v0/b/ch...   14525B
# 2  https://firebasestorage.googleapis.com/v0/b/ch...   75585B
# ...

# %%
rules = [
    {
        "conditions": {
            "all": [{"name": "videos_by_user", "operator": "less_than", "value": 2,}]
        },
        "actions": [{"name": "set_importance", "params": {"importance": 1},},],
    },
    {
        "conditions": {
            "all": [
                {"name": "videos_by_user", "operator": "less_than", "value": 4,},
                {"name": "videos_by_user", "operator": "greater_than_or_equal_to", "value": 2,},
            ]
        },
        "actions": [{"name": "set_importance", "params": {"importance": 3},},],
    },
    
    {
        "conditions": {
            "all": [
                {"name": "videos_by_user", "operator": "greater_than_or_equal_to", "value": 4,},
            ]
        },
        "actions": [{"name": "set_importance", "params": {"importance": 6},},],
    },
]

# %%
videos = [Video(kwargs) for kwargs in df.to_dict(orient='records')]

# %%
for video in videos:
    run_all(rule_list=rules,
            defined_variables=VideoVariables(video),
            defined_actions=VideoActions(video)
           )

# %%
videos_importance = [video.__dict__ for video in  videos]

videos_importance_sorted = sorted(videos_importance,key=lambda video: video["importance"], reverse=True)

# %%
videos_importance_sorted
# Out:
# [{'id': '56b38c82-be98-463c-8c52-90dd42d124b8',
#   'title': 'the office - Pam pong',
#   'videos_by_user': 4,
#   'importance': 6},
#  {'id': 'ba771d09-e114-465b-b523-f3a50cdd8b8b',
#   'title': 'sjshsj',
#   'videos_by_user': 4,
#   'importance': 6},
#  {'id': '68b432b7-6419-4f05-9358-de3395110290',
#   'title': 'ymik',
#   'videos_by_user': 4,
#   'importance': 6},
#  {'id': '9874951e-caf6-4d6b-9000-3a5d77f9a8b5',
#   'title': 'Nacho.o works',
#   'videos_by_user': 4,
#   'importance': 6},
#  {'id': 'f0b857db-2083-4d86-8090-12342108277d',
#   'title': 'un videaso',
#   'videos_by_user': 3,
#   'importance': 3},
#  {'id': 'cbee4f93-3fdb-4ae3-a0d7-aa05cb4c5502',
#   'title': 'sam',
#   'videos_by_user': 3,
#   'importance': 3},
#  {'id': '37bfb94e-8a2a-4bfa-8d42-5f1c44fa7dbb',
#   'title': 'un video',
#   'videos_by_user': 3,
#   'importance': 3},
#  {'id': 'c1b0b83f-69c0-48fe-937b-83883180fb16',
#   'title': 'rick on love',
#   'videos_by_user': 2,
#   'importance': 3},
# ...
